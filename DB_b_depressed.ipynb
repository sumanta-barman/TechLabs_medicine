# %%
import pandas as pd
cv = pd.read_csv("b_depressed.csv")

# %%
cv.head()
# Out:
#    Survey_id  Ville_id  ...  no_lasting_investmen  depressed
# 0        926        91  ...            28292707.0          0
# 1        747        57  ...            28292707.0          1
# 2       1190       115  ...            28292707.0          0
# 3       1065        97  ...            69219765.0          0
# 4        806        42  ...            43419447.0          0
#
# [5 rows x 23 columns]

# %%
cv.isna().sum()
# Out:
# Survey_id                 0
# Ville_id                  0
# sex                       0
# Age                       0
# Married                   0
# Number_children           0
# education_level           0
# total_members             0
# gained_asset              0
# durable_asset             0
# save_asset                0
# living_expenses           0
# other_expenses            0
# incoming_salary           0
# incoming_own_farm         0
# incoming_business         0
# incoming_no_business      0
# incoming_agricultural     0
# farm_expenses             0
# labor_primary             0
# lasting_investment        0
# no_lasting_investmen     20
# depressed                 0
# dtype: int64

# %%
cv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1429 entries, 0 to 1428
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Survey_id              1429 non-null   int64
#  1   Ville_id               1429 non-null   int64
#  2   sex                    1429 non-null   int64
#  3   Age                    1429 non-null   int64
#  4   Married                1429 non-null   int64
#  5   Number_children        1429 non-null   int64
#  6   education_level        1429 non-null   int64
#  7   total_members          1429 non-null   int64
#  8   gained_asset           1429 non-null   int64
#  9   durable_asset          1429 non-null   int64
#  10  save_asset             1429 non-null   int64
#  11  living_expenses        1429 non-null   int64
#  12  other_expenses         1429 non-null   int64
#  13  incoming_salary        1429 non-null   int64
#  14  incoming_own_farm      1429 non-null   int64
#  15  incoming_business      1429 non-null   int64
#  16  incoming_no_business   1429 non-null   int64
#  17  incoming_agricultural  1429 non-null   int64
#  18  farm_expenses          1429 non-null   int64
#  19  labor_primary          1429 non-null   int64
#  20  lasting_investment     1429 non-null   int64
#  21  no_lasting_investmen   1409 non-null   float64
#  22  depressed              1429 non-null   int64
# dtypes: float64(1), int64(22)
# memory usage: 256.9 KB

# %%
cv.set_index('Survey_id', inplace=True)

# %%
cv.head()
# Out:
#            Ville_id  sex  ...  no_lasting_investmen  depressed
# Survey_id                 ...
# 926              91    1  ...            28292707.0          0
# 747              57    1  ...            28292707.0          1
# 1190            115    1  ...            28292707.0          0
# 1065             97    1  ...            69219765.0          0
# 806              42    0  ...            43419447.0          0
#
# [5 rows x 22 columns]

# %%
cv.query('depressed == 1').head()
# Out:
#            Ville_id  sex  ...  no_lasting_investmen  depressed
# Survey_id                 ...
# 747              57    1  ...            28292707.0          1
# 849             130    0  ...            55608922.0          1
# 540              52    1  ...            28292707.0          1
# 603             100    1  ...            71201668.0          1
# 1001            207    1  ...            28292707.0          1
#
# [5 rows x 22 columns]

# %%
cv.query('depressed == 1').count()
# Out:
# Ville_id                 238
# sex                      238
# Age                      238
# Married                  238
# Number_children          238
# education_level          238
# total_members            238
# gained_asset             238
# durable_asset            238
# save_asset               238
# living_expenses          238
# other_expenses           238
# incoming_salary          238
# incoming_own_farm        238
# incoming_business        238
# incoming_no_business     238
# incoming_agricultural    238
# farm_expenses            238
# labor_primary            238
# lasting_investment       238
# no_lasting_investmen     235
# depressed                238
# dtype: int64

# %%
cv.groupby(by='depressed').size()
# Out:
# depressed
# 0    1191
# 1     238
# dtype: int64

# %%
cv.describe()
# Out:
#           Ville_id          sex  ...  no_lasting_investmen    depressed
# count  1429.000000  1429.000000  ...          1.409000e+03  1429.000000
# mean     76.286214     0.918125  ...          3.360385e+07     0.166550
# std      66.444012     0.274271  ...          2.160228e+07     0.372704
# min       1.000000     0.000000  ...          1.263120e+05     0.000000
# 25%      24.000000     1.000000  ...          2.064203e+07     0.000000
# 50%      57.000000     1.000000  ...          2.829271e+07     0.000000
# 75%     105.000000     1.000000  ...          4.151762e+07     0.000000
# max     292.000000     1.000000  ...          9.965119e+07     1.000000
#
# [8 rows x 22 columns]

# %%
cv = cv.dropna()

# %%
cv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1409 entries, 926 to 231
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Ville_id               1409 non-null   int64
#  1   sex                    1409 non-null   int64
#  2   Age                    1409 non-null   int64
#  3   Married                1409 non-null   int64
#  4   Number_children        1409 non-null   int64
#  5   education_level        1409 non-null   int64
#  6   total_members          1409 non-null   int64
#  7   gained_asset           1409 non-null   int64
#  8   durable_asset          1409 non-null   int64
#  9   save_asset             1409 non-null   int64
#  10  living_expenses        1409 non-null   int64
#  11  other_expenses         1409 non-null   int64
#  12  incoming_salary        1409 non-null   int64
#  13  incoming_own_farm      1409 non-null   int64
#  14  incoming_business      1409 non-null   int64
#  15  incoming_no_business   1409 non-null   int64
#  16  incoming_agricultural  1409 non-null   int64
#  17  farm_expenses          1409 non-null   int64
#  18  labor_primary          1409 non-null   int64
#  19  lasting_investment     1409 non-null   int64
#  20  no_lasting_investmen   1409 non-null   float64
#  21  depressed              1409 non-null   int64
# dtypes: float64(1), int64(21)
# memory usage: 253.2 KB

# %%
from sklearn.model_selection import train_test_split

X= cv.iloc[:, :-1].values
y= cv.iloc[:,4].values
X_train, X_test, y_train, y_test = train_test_split (X,y, test_size=0.3,random_state=0)

# %%
from sklearn.preprocessing import Normalizer
scaler = Normalizer().fit(X_train)
normalized_X = scaler.transform(X_train)
normalized_X_test = scaler.transform(X_test)

# %%
from sklearn.neighbors import KNeighborsClassifier
classifier = KNeighborsClassifier (n_neighbors=5)
classifier.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#                      weights='uniform')

# %%
y_pred = classifier.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt

matriz_confusion = confusion_matrix(y_test, y_pred)
from mlxtend.plotting import plot_confusion_matrix
fig, ax = plot_confusion_matrix(conf_mat = matriz_confusion)
plt.show()
